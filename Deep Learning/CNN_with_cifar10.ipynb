# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.datasets import cifar10

# %%
(x_train, y_train), (x_test,y_test) = cifar10.load_data()
x_train = x_train.astype('float32')/ 255.0
x_test = x_test.astype('float32')/ 255.0

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(32,32,3)),
        layers.Conv2D(32, 3, padding='valid', activation='relu'),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Conv2D(64, 3, padding='valid', activation='relu'),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Conv2D(128, 3, padding='valid', activation='relu'),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(10),
    ]
)
model.summary()

model.compile( 
    loss =keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = keras.optimizers.Adam(0.0003),
    metrics=['accuracy'],
)
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_25 (Conv2D)              │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │       131,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train, batch_size=64, epochs=10, verbose=2)
model.evaluate(x_test, y_test, batch_size=64, verbose=2)
# Out:
# Epoch 1/10
# 782/782 - 16s - 20ms/step - accuracy: 0.3888 - loss: 1.6649
# Epoch 2/10
# 782/782 - 15s - 19ms/step - accuracy: 0.5155 - loss: 1.3449
# Epoch 3/10
# 782/782 - 15s - 19ms/step - accuracy: 0.5645 - loss: 1.2232
# Epoch 4/10
# 782/782 - 16s - 20ms/step - accuracy: 0.6050 - loss: 1.1265
# Epoch 5/10
# 782/782 - 16s - 20ms/step - accuracy: 0.6382 - loss: 1.0384
# Epoch 6/10
# 782/782 - 16s - 20ms/step - accuracy: 0.6612 - loss: 0.9767
# Epoch 7/10
# 782/782 - 16s - 20ms/step - accuracy: 0.6792 - loss: 0.9230
# Epoch 8/10
# 782/782 - 16s - 20ms/step - accuracy: 0.6942 - loss: 0.8779
# Epoch 9/10
# 782/782 - 16s - 20ms/step - accuracy: 0.7094 - loss: 0.8402
# Epoch 10/10
# 782/782 - 16s - 20ms/step - accuracy: 0.7251 - loss: 0.7974
# 157/157 - 2s - 10ms/step - accuracy: 0.6946 - loss: 0.8849
# [0.8849180936813354, 0.694599986076355]

# %% [markdown]
# Functionsl Model

# %%
def my_model():
    inputs = keras.Input(shape=(32,32,3))
    x= layers.Conv2D(
        32,3, padding='same', kernel_regularizer=regularizers.l2(0.01)
                     )(inputs)
    x= layers.BatchNormalization()(x)
    x= keras.activations.relu(x)
    x= layers.MaxPooling2D()(x)
    x= layers.Conv2D(
        64,5, padding='same', kernel_regularizer=regularizers.l2(0.01))(x)
    x= layers.BatchNormalization()(x)
    x= keras.activations.relu(x)
    x= layers.Conv2D(128,3, padding='same', kernel_regularizer=regularizers.l2(0.01))(x)
    x= layers.BatchNormalization()(x)
    x= keras.activations.relu(x)
    x= layers.Flatten()(x)
    x = layers.Dense(64, activation='relu',  kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(10)(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = my_model()

model.compile( 
    loss =keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = keras.optimizers.Adam(0.0003),
    metrics=['accuracy'],
)

model.fit(x_train,y_train, batch_size=64, epochs=20, verbose=2)
model.evaluate(x_test, y_test, batch_size=64, verbose=2)
# Out:
# Epoch 1/20
# 782/782 - 122s - 156ms/step - accuracy: 0.1569 - loss: 3.1152
# Epoch 2/20
# 782/782 - 114s - 146ms/step - accuracy: 0.1791 - loss: 2.2304
# Epoch 3/20
# 782/782 - 116s - 148ms/step - accuracy: 0.2248 - loss: 2.0920
# Epoch 4/20
# 782/782 - 113s - 145ms/step - accuracy: 0.2697 - loss: 1.9797
# Epoch 5/20
# 782/782 - 113s - 145ms/step - accuracy: 0.2971 - loss: 1.9094
# Epoch 6/20
# 782/782 - 114s - 146ms/step - accuracy: 0.3172 - loss: 1.8549
# Epoch 7/20
# 782/782 - 117s - 149ms/step - accuracy: 0.3383 - loss: 1.8063
# Epoch 8/20
# 782/782 - 117s - 150ms/step - accuracy: 0.3553 - loss: 1.7769
# Epoch 9/20
# 782/782 - 117s - 150ms/step - accuracy: 0.3794 - loss: 1.7414
# Epoch 10/20
# 782/782 - 118s - 150ms/step - accuracy: 0.4001 - loss: 1.6936
# Epoch 11/20
# 782/782 - 116s - 148ms/step - accuracy: 0.4210 - loss: 1.6571
# Epoch 12/20
# 782/782 - 108s - 138ms/step - accuracy: 0.4342 - loss: 1.6273
# Epoch 13/20
# 782/782 - 107s - 137ms/step - accuracy: 0.4461 - loss: 1.6052
# Epoch 14/20
# 782/782 - 107s - 137ms/step - accuracy: 0.4549 - loss: 1.5913
# Epoch 15/20
# 782/782 - 106s - 136ms/step - accuracy: 0.4605 - loss: 1.5747
# Epoch 16/20
# 782/782 - 108s - 138ms/step - accuracy: 0.4659 - loss: 1.5565
# Epoch 17/20
# 782/782 - 107s - 137ms/step - accuracy: 0.4722 - loss: 1.5480
# Epoch 18/20
# 782/782 - 106s - 136ms/step - accuracy: 0.4731 - loss: 1.5449
# Epoch 19/20
# 782/782 - 106s - 136ms/step - accuracy: 0.4763 - loss: 1.5396
# Epoch 20/20
# 782/782 - 19646s - 25s/step - accuracy: 0.4797 - loss: 1.5337
# 157/157 - 4s - 27ms/step - accuracy: 0.6208 - loss: 1.3207
# [1.3206864595413208, 0.6208000183105469]
