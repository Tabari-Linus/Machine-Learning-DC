# %%
import tensorflow as tf
# from tensorflow.python.ops import rnn, rnn_cell
from tensorflow.keras.utils import to_categorical
import numpy as np
from sklearn.model_selection import train_test_split
mnist = './Data/mnist.npz'

# %%
# Model Hyperparameters
time_steps = 28       # Rows in the image
input_size = 28       # Columns in each row (input features per step)
num_classes = 10      # Digits 0-9
batch_size = 64
epochs = 10
hidden_units = 128

# Define the RNN model
def build_rnn_model():
    model = tf.keras.Sequential([
        tf.keras.layers.SimpleRNN(hidden_units, input_shape=(time_steps, input_size), activation='tanh'),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    return model

# %%
# Load the data
with np.load(mnist) as data:
    x_train = data['x_train']
    y_train = data['y_train']
    x_test = data['x_test']
    y_test = data['y_test']

# Normalize the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Compile the model
# Build the model
model = build_rnn_model()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


# Train the model
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# c:\Users\Shadow\anaconda3\envs\env\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - accuracy: 0.8139 - loss: 0.6179 - val_accuracy: 0.9448 - val_loss: 0.1875
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9430 - loss: 0.1953 - val_accuracy: 0.9558 - val_loss: 0.1493
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9559 - loss: 0.1537 - val_accuracy: 0.9627 - val_loss: 0.1318
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9623 - loss: 0.1270 - val_accuracy: 0.9604 - val_loss: 0.1357
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9668 - loss: 0.1150 - val_accuracy: 0.9588 - val_loss: 0.1394
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9657 - loss: 0.1181 - val_accuracy: 0.9679 - val_loss: 0.1151
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9701 - loss: 0.1059 - val_accuracy: 0.9692 - val_loss: 0.1028
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9729 - loss: 0.0972 - val_accuracy: 0.9666 - val_loss: 0.1156
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9708 - loss: 0.1004 - val_accuracy: 0.9706 - val_loss: 0.1010
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9739 - loss: 0.0902 - val_accuracy: 0.9688 - val_loss: 0.1048
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9643 - loss: 0.1158
# Test accuracy: 0.9688
