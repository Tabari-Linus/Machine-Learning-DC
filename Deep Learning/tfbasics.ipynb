# %%
import tensorflow as tf 
import numpy as np

x1 = tf.constant(5)
x2 = tf.constant(6)

# result = x1 * x2
tf_result = tf.multiply(x1,x2)

# print(result)
print(tf_result)
print(tf_result.numpy())
# Out:
# tf.Tensor(30, shape=(), dtype=int32)
# 30
